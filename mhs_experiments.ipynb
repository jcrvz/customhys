# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import scipy.stats as st
import seaborn as sns
from mpmath import *
from decimal import Decimal
from timeit import default_timer as timer
import json

import tools as tl
import benchmark_func as bf
from hyperheuristic import Hyperheuristic
from metaheuristic import Metaheuristic
from experiment import read_config_file

# %%
sns.set(context="paper", font_scale=1.8, palette="husl", style="ticks",
        rc={'font.family': 'serif', 'font.size': 18,
            "xtick.major.top": False, "ytick.major.right": False})
plt.rc('font', size=18) 

# Saving images flag
is_saving = True
show_plots = True
saving_format = 'png'

figures_folder = 'data_files/exp_figures/'
experiment_folder = 'data_files/exp_output'
ml_model_folder = "./data_files/ml_models_times/"
exp_label = 'default_nn_best_double_lstm'
bm_exp_label = 'basic_metaheuristic'

if is_saving:
    # Read (or create if so) a folder for storing images
    if not os.path.isdir(figures_folder):
        os.mkdir(figures_folder)

# %%
files = os.listdir(ml_model_folder)
files = [file for file in files if 'DS_S' not in file]

# Number of dimensions
dimensions = [2, 10, 30, 50]
num_dims = len(dimensions)

problems = list(set(file.split('-')[0] for file in files))
len(problems), dimensions
# Out:
# (119, [2, 10, 30, 50])

# %%
data = tl.read_json('./data_files/exp_output/'+exp_label+'.json')

# %%
def sort_dataset(dataset):
    # Sort the results of the 428 problems in lexicographically order
    list_pair_results = list(zip(dataset['problem'],
                                 dataset['dimensions'],
                                 dataset['results']))
    list_pair_results.sort()
    dataset['problem'], dataset['dimensions'], dataset['results'] = [], [], []
    for problem, dimension, result in list_pair_results:
        dataset['problem'].append(problem)
        dataset['dimensions'].append(dimension)
        dataset['results'].append(result)
        
def filter_by_dimensions(dataset):
    # Filter the dataset allowing only the dimensions from 'dimensions' list.
    # The usercase is for the basic metaheuristics that has results for extra 
    # dimensions out of scope of this paper.
    allowed_dim_inds = [index for d in dimensions for index in tl.listfind(dataset['dimensions'], d)]
    dict_filtered = {key: [val[x] for x in allowed_dim_inds] for key, val in dataset.items()}
    sort_dataset(dict_filtered)
    return dict_filtered

# %%
# Read operators and find their alias
collections = ['default.txt', 'basicmetaheuristics.txt']

encoded_heuristic_space = dict()
for collection_file in collections:
    with open('./collections/' + collection_file, 'r') as operators_file:
        encoded_heuristic_space[collection_file] = [eval(line.rstrip('\n')) for line in operators_file]

# Search operator aliases
perturbator_alias = {
    'random_search': 'RS',
    'central_force_dynamic': 'CF',
    'differential_mutation': 'DM',
    'firefly_dynamic': 'FD',
    'genetic_crossover': 'GC',
    'genetic_mutation': 'GM',
    'gravitational_search': 'GS',
    'random_flight': 'RF',
    'local_random_walk': 'RW',
    'random_sample': 'RX',
    'spiral_dynamic': 'SD',
    'swarm_dynamic': 'PS'}

selector_alias = {'greedy': 'g', 'all': 'd', 'metropolis': 'm', 'probabilistic': 'p'}

operator_families = {y: i for i, y in enumerate(sorted([x for x in perturbator_alias.values()]))}

# Pre-build the alias list
heuristic_space = dict()
for collection_file in collections:
    if all(isinstance(x, tuple) for x in encoded_heuristic_space[collection_file]):
        heuristic_space[collection_file] = [perturbator_alias[x[0]] + selector_alias[x[2]]
                                            for x in encoded_heuristic_space[collection_file]]

# %%
# Read basic metaheuristics
basic_mhs_collection = encoded_heuristic_space['basicmetaheuristics.txt']

# Read basic metaheuristics cardinality
basic_mhs_cadinality = [1 if isinstance(x, tuple) else len(x) for x in basic_mhs_collection]

# Load data from basic metaheuristics
basic_mhs_data = filter_by_dimensions(tl.read_json(f'{experiment_folder}/basic-metaheuristics-data_v2.json'))

# Mathematical attributes
chosen_categories = ['Differentiable', 'Unimodal']
case_label = 'DU'

# Call the problem categories
problem_features = bf.list_functions(fts=chosen_categories)
categories = sorted(set([problem_features[x]['Code'] for x in basic_mhs_data['problem']]), reverse=True)

# %%
# Retrive the results per experiment
data_frame = filter_by_dimensions(data)

# Summary
id = 'dlstm'
data_info = {
    'Dim': [int(x) for x in data_frame['dimensions']],
    'Pop': 30,
    'Problem': data_frame['problem'],
    'Cat': [problem_features[x]['Code'] for x in data_frame['problem']],
    'mhs': [x['encoded_solution'] for x in data_frame['results']],
    'hist': [x['hist_fitness'] for x in data_frame['results']]
}

# %%
def get_correct_id(problem_name, dimension):
  for id in range(len(data_info['Problem'])):
    correct_problem = data_info['Problem'][id] == problem_name
    correct_dimension = data_info['Dim'][id] == dimension
    if correct_problem and correct_dimension:
      return id
  return -1

# %%
"""
exp_config, hh_config, prob_config = read_config_file(exp_label)
# Message to print and to store in folders
problem_name = 'Sphere'
dimension = 2
label = '{}-{}D-{}'.format(problem_name, dimension, exp_label)

# Get and format the problem
# problem = eval('bf.{}({})'.format(problem, dimension))
problem = bf.choose_problem(problem_name, dimension)

problem.set_offset_domain(2)
problem.set_offset_function(3)
problem.set_scale_domain(1.5)
problem.set_scale_function(4)
problem.set_noise_type('normal')
problem.set_noise_level(2)

problem_to_solve = problem.get_formatted_problem(True, ['Differentiable', 'Separable', 'Unimodal'])
from optproblems.cec2005 import F1
fun = F1(2, None)
problem_to_solve['function'] = fun

# Call the hyper-heuristic object
hh = Hyperheuristic(heuristic_space=exp_config['heuristic_collection_file'],
                        problem=problem_to_solve, parameters=hh_config,
                        file_label=label, weights_array=None)
"""
# Out:
# "\nexp_config, hh_config, prob_config = read_config_file(exp_label)\n# Message to print and to store in folders\nproblem_name = 'Sphere'\ndimension = 2\nlabel = '{}-{}D-{}'.format(problem_name, dimension, exp_label)\n\n# Get and format the problem\n# problem = eval('bf.{}({})'.format(problem, dimension))\nproblem = bf.choose_problem(problem_name, dimension)\n\nproblem.set_offset_domain(2)\nproblem.set_offset_function(3)\nproblem.set_scale_domain(1.5)\nproblem.set_scale_function(4)\nproblem.set_noise_type('normal')\nproblem.set_noise_level(2)\n\nproblem_to_solve = problem.get_formatted_problem(True, ['Differentiable', 'Separable', 'Unimodal'])\nfrom optproblems.cec2005 import F1\nfun = F1(2, None)\nproblem_to_solve['function'] = fun\n\n# Call the hyper-heuristic object\nhh = Hyperheuristic(heuristic_space=exp_config['heuristic_collection_file'],\n                        problem=problem_to_solve, parameters=hh_config,\n                        file_label=label, weights_array=None)\n"

# %%
def get_best_mhs(problem_name, dimension):
  id = get_correct_id(problem_name, dimension)
  hists = [historial[-1] for historial in data_info['hist'][id]]
  optimal_position = np.argmin(hists)
  return data_info['mhs'][id][optimal_position]

# %%
exp_config, hh_config, prob_config = read_config_file(exp_label)

def get_evaluation(problem_name, dimension, problem_to_solve):
  label = '{}-{}D-{}'.format(problem_name, dimension, exp_label)
  hh = Hyperheuristic(heuristic_space=exp_config['heuristic_collection_file'],
                      problem=problem_to_solve, parameters=hh_config,
                      file_label=label, weights_array=None)
  mhs =  get_best_mhs(problem_name, dimension)
  hh.parameters['num_replicas'] = 30
  hh.num_iterations = 1
  start_time = timer()
  results = hh.evaluate_candidate_solution(mhs)
  end_time = timer() - start_time
  return (end_time, results)

def get_from_trained_model(problem_name, dimension, problem_to_solve):
  label = '{}-{}D-{}'.format(problem_name, dimension, exp_label)
  hh = Hyperheuristic(heuristic_space=exp_config['heuristic_collection_file'],
                      problem=problem_to_solve, parameters=hh_config,
                      file_label=label, weights_array=None)
  start_time = timer()
  hh.parameters['num_replicas'] = 30
  results = hh._solve_neural_network()
  end_time = timer() - start_time
  return (end_time, results)
  

bm_exp_config, bm_hh_config, bm_prob_config = read_config_file(bm_exp_label)
def get_bm_evaluation(func_name, dimension, problem_to_solve):
  label = '{}-{}D-{}'.format(func_name, dimension, bm_exp_label)
  hh = Hyperheuristic(heuristic_space=bm_exp_config['heuristic_collection_file'],
                      problem=problem_to_solve, parameters=bm_hh_config,
                      file_label=label, weights_array=None)
  results = hh.basic_metaheuristics()
  print(f'{func_name} with bmhs done!')
  return results

# %%
cec_relation = {
  'F1': ['Sphere'],
  'F2': ['Schwefel12'],# 'Schwefel'],
  'F4': ['Schwefel'],# 'Schwefel12'],
  'F5': ['Schwefel226'],# 'Schwefel'],
  'F6': ['Rosenbrock'],
  'F7': ['Griewank'],
  'F8': ['Ackley1'],# 'Ackley4'],
  'F9': ['Rastrigin'],
  'F10': ['Rastrigin'],
  'F11': ['Weierstrass'],
  'F13': ['Rosenbrock', 'Griewank'],
  'F14': ['SchafferN1']#, 'SchafferN2', 'SchafferN3', 'SchafferN4', 'SchafferN6'],
}

cec_boundaries = {
  'F1': (-100, 100),
  'F2': (-100, 100),
  'F4': (-100, 100),
  'F5': (-100, 100),
  'F6': (-100, 100),
  'F7': (0, 600),
  'F8': (-32, 32),
  'F9': (-5, 5),
  'F10': (-5, 5),
  'F11': (-0.5, 0.5),
  'F13': (-3, 1),
  'F14': (-100, 100),
}

cec_constrained = {
  'F1': True,
  'F2': True,
  'F4': True,
  'F5': True,
  'F6': True,
  'F7': False,
  'F8': True,
  'F9': True,
  'F10': True,
  'F11': True,
  'F13': True,
  'F14': True,
}

# %%
from optproblems.cec2005 import *

results_dlstm = {
  'func_name': [],
  'base_func': [],
  'dimension': [],
  'performance': [],
  'fitness': [],
  'time': [],
}
def get_cec_function_formatted(f_name, dimension):
  f_initializer = eval(f_name)
  if f_name == 'F7':
    f_function = f_initializer(dimension)
  else:
    f_function = f_initializer(dimension, None)
  pre_bound = cec_boundaries[f_name]
  boundaries = ([pre_bound[0]]*dimension, [pre_bound[1]]*dimension)
  constrained = cec_constrained[f_name]
  problem_to_solve = {
    'function': f_function, 
    'boundaries': boundaries, 
    'is_constrained': constrained
  }
  return problem_to_solve
  
for f_name, bf_names in cec_relation.items():
  for dimension in dimensions:
    
    cec_function = get_cec_function_formatted(f_name, dimension)
    """
    label = '{}-{}D-{}_CEC05'.format(f_name, dimension, exp_label)
    hh = Hyperheuristic(heuristic_space=exp_config['heuristic_collection_file'],
                        problem=cec_function, parameters=hh_config,
                        file_label=label, weights_array=None)
    hh.parameters['verbose']=True
    hh.parameters['model_params']['epochs'] = 3
    start_time = timer()
    res = hh._solve_neural_network()
    end_time = timer() - start_time
    final_fit = [x[-1] for x in res[0]]
    performance_mhs = np.median(final_fit) + st.iqr(final_fit)
    results_dlstm['func_name'].append(f_name)
    results_dlstm['base_func'].append('neural network')
    results_dlstm['dimension'].append(dimension)
    results_dlstm['performance'].append(performance_mhs)
    results_dlstm['fitness'].append(res[0])
    results_dlstm['time'].append(end_time)    
    """
    
    for problem_name in bf_names:

      end_time, res = get_evaluation(problem_name, dimension, cec_function)
      performance_mhs = res[0]
      historical_replicas = res[1]['historical']
      hist_fitness = [[int(fitness) for fitness in replica['fitness']] for replica in historical_replicas]
      best_fitness = min(x[-1] for x in hist_fitness)
      
      results_dlstm['func_name'].append(f_name)
      results_dlstm['base_func'].append(problem_name)
      results_dlstm['dimension'].append(dimension)
      results_dlstm['performance'].append(performance_mhs)
      results_dlstm['fitness'].append(hist_fitness)
      results_dlstm['time'].append(end_time)
      print(f_name, problem_name, dimension, best_fitness, end_time)

# %%
import json
json_object = json.dumps(results_dlstm, indent=4)
with open('dlstm_cec2005_results.json', 'w') as outfile:
  outfile.write(json_object)

# %%
results_dlstm_from_trained = {
  'func_name': [],
  'base_func': [],
  'dimension': [],
  'performance': [],
  'fitness': [],
  'time': [],
}
for f_name, bf_names in cec_relation.items():
  for dimension in dimensions:
    
    cec_function = get_cec_function_formatted(f_name, dimension)
    
    for problem_name in bf_names:

      end_time, res = get_from_trained_model(problem_name, dimension, cec_function)
      hist_fitness = res[0]
      last_fitness = [x[-1] for x in hist_fitness]
      performance_mhs = np.median(last_fitness) + st.iqr(last_fitness)
      best_fitness = min(x[-1] for x in hist_fitness)
      
      results_dlstm_from_trained['func_name'].append(f_name)
      results_dlstm_from_trained['base_func'].append(problem_name)
      results_dlstm_from_trained['dimension'].append(dimension)
      results_dlstm_from_trained['performance'].append(performance_mhs)
      results_dlstm_from_trained['fitness'].append(hist_fitness)
      results_dlstm_from_trained['time'].append(end_time)
      print(f_name, problem_name, dimension, best_fitness, end_time)

json_object = json.dumps(results_dlstm_from_trained, indent=4)
with open('dlstm_from_trained_model_cec2005_results.json', 'w') as outfile:
  outfile.write(json_object)
# Out:
# Metal device set to: Apple M1 Pro
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
#
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_224 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_225 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# F1 Sphere 2 -450.0 350.627701375
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_226 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_227 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# F1 Sphere 10 -449.99994329270777 1079.1201958340002
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_228 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_229 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# F1 Sphere 30 -285.2369971899556 1181.2999925000001
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_230 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_231 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# F1 Sphere 50 2669.794071543517 1055.4062423330001
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_160 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_161 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#
will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# F10 Rastrigin 50 24.600735928587824 814.2610584170034
# WARNING:tensorflow:Layer lstm_72 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_73 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_280 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_281 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# F11 Weierstrass 2 90.00000809868126 270.6298655419996
# WARNING:tensorflow:Layer lstm_74 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_75 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_282 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_283 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# F11 Weierstrass 10 92.3651468735545 365.69971770900156
# WARNING:tensorflow:Layer lstm_76 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_77 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_284 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_285 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# F11 Weierstrass 30 115.20896442688931 660.1199990839996
# WARNING:tensorflow:Layer lstm_78 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_79 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_286 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_287 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# F11 Weierstrass 50 138.09927442353012 948.6203052919991
# WARNING:tensorflow:Layer lstm_80 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_81 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_192 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_193 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# F13 Rosenbrock 2 -130.0 291.7150279589987
# WARNING:tensorflow:Layer lstm_82 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_83 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_96 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_97 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# F13 Griewank 2 -130.0 269.093316167
# WARNING:tensorflow:Layer lstm_84 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_85 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_194 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_195 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# F13 Rosenbrock 10 -129.5726622941532 707.3012669579985
# WARNING:tensorflow:Layer lstm_86 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_87 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_98 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_99 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# F13 Griewank 10 -129.6272895506564 383.9084749169997
# WARNING:tensorflow:Layer lstm_88 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_89 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_196 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_197 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# F13 Rosenbrock 30 -123.97506337598337 703.6560474999969
# WARNING:tensorflow:Layer lstm_90 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_91 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_100 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_101 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# F13 Griewank 30 -121.18796630408276 606.286655625001
# WARNING:tensorflow:Layer lstm_92 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_93 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_198 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_199 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# F13 Rosenbrock 50 -111.19450454366569 748.734110292
# WARNING:tensorflow:Layer lstm_94 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_95 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_102 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_103 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# F13 Griewank 50 -110.65830875399328 728.7604154170003
# WARNING:tensorflow:Layer lstm_96 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_97 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_152 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_153 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# F14 SchafferN1 2 -299.99093242566767 106.14541070900304
# WARNING:tensorflow:Layer lstm_98 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_99 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_154 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_155 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# F14 SchafferN1 10 -296.745863304803 133.9440991670017
# WARNING:tensorflow:Layer lstm_100 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_101 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_156 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_157 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# F14 SchafferN1 30 -286.61472384259207 83.19392095799776
# WARNING:tensorflow:Layer lstm_102 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_103 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_158 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_159 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# F14 SchafferN1 50 -276.7282306900249 82.9182914999983

# %%
len(results_dlstm_from_trained['func_name'])
# Out:
# 24

# %%
results_bmhs = {
  'func_name': [],
  'base_func': [],
  'dimension': [],
  'performance': [],
  'fitness': [],
  'time': [],
}

for f_name in cec_relation.keys():
    for dimension in dimensions:

      cec_function = get_cec_function_formatted(f_name, dimension)
      
      res = get_bm_evaluation(f_name, dimension, cec_function)

      for id, operators in enumerate(encoded_heuristic_space['basicmetaheuristics.txt']):
        problem_name = operators[0]
        if isinstance(problem_name, tuple):
          problem_name = problem_name[0]
        performance_mhs = res['performance'][id]
        hist_fitness = res['fitness'][id]
        end_time = res['time'][id]
        
        results_bmhs['func_name'].append(f_name)
        results_bmhs['base_func'].append(problem_name)
        results_bmhs['dimension'].append(dimension)
        results_bmhs['performance'].append(performance_mhs)
        results_bmhs['fitness'].append(hist_fitness)
        results_bmhs['time'].append(end_time)
        best_fitness = min(x[-1] for x in hist_fitness)
        print(f_name, problem_name, dimension, performance_mhs, end_time)
# Out:
# F1-2D-basic_metaheuristic :: BasicMH 1 of 66, Perf: -441.15853476378345
# F1-2D-basic_metaheuristic :: BasicMH 2 of 66, Perf: -449.9925349947022
# F1-2D-basic_metaheuristic :: BasicMH 3 of 66, Perf: -449.96574428837033
# F1-2D-basic_metaheuristic :: BasicMH 4 of 66, Perf: -448.18774519300797
# F1-2D-basic_metaheuristic :: BasicMH 5 of 66, Perf: -449.99702266725376
# F1-2D-basic_metaheuristic :: BasicMH 6 of 66, Perf: -449.9792900000848
# F1-2D-basic_metaheuristic :: BasicMH 7 of 66, Perf: -448.7380751434638
# F1-2D-basic_metaheuristic :: BasicMH 8 of 66, Perf: -449.99849504575815
# F1-2D-basic_metaheuristic :: BasicMH 9 of 66, Perf: -449.9770937823502
# F1-2D-basic_metaheuristic :: BasicMH 10 of 66, Perf: -446.1479053889491
# F1-2D-basic_metaheuristic :: BasicMH 11 of 66, Perf: -449.9997829836682
# F1-2D-basic_metaheuristic :: BasicMH 12 of 66, Perf: -449.99657162322734
# F1-2D-basic_metaheuristic :: BasicMH 13 of 66, Perf: -446.7810700470935
# F1-2D-basic_metaheuristic :: BasicMH 14 of 66, Perf: -442.52321012410437
# F1-2D-basic_metaheuristic :: BasicMH 15 of 66, Perf: -449.9999954631016
# F1-2D-basic_metaheuristic :: BasicMH 16 of 66, Perf: -449.9997395922324
# F1-2D-basic_metaheuristic :: BasicMH 17 of 66, Perf: -449.80355003882204
# F1-2D-basic_metaheuristic :: BasicMH 18 of 66, Perf: -446.903636073305
# F1-2D-basic_metaheuristic :: BasicMH 19 of 66, Perf: -446.2738876665126
# F1-2D-basic_metaheuristic :: BasicMH 20 of 66, Perf: -449.926460099417
# F1-2D-basic_metaheuristic :: BasicMH 21 of 66, Perf: -442.99152202157455
# F1-2D-basic_metaheuristic :: BasicMH 22 of 66, Perf: -417.3304960581008
# F1-2D-basic_metaheuristic :: BasicMH 23 of 66, Perf: -444.9856980129988
# F1-2D-basic_metaheuristic :: BasicMH 24 of 66, Perf: -440.340189190439
# F1-2D-basic_metaheuristic :: BasicMH 25 of 66, Perf: -435.9372473074683
# F1-2D-basic_metaheuristic :: BasicMH 26 of 66, Perf: -443.17353560853076
# F1-2D-basic_metaheuristic :: BasicMH 27 of 66, Perf: -436.1850312472046
# F1-2D-basic_metaheuristic :: BasicMH 28 of 66, Perf: -437.3437468805509
# F1-2D-basic_metaheuristic :: BasicMH 29 of 66, Perf: -444.8842166906831
# F1-2D-basic_metaheuristic :: BasicMH 30 of 66, Perf: -435.97230598157637
# F1-2D-basic_metaheuristic :: BasicMH 31 of 66, Perf: 60.67341133868928
# F1-2D-basic_metaheuristic :: BasicMH 32 of 66, Perf: -21.961594455487784
# F1-2D-basic_metaheuristic :: BasicMH 33 of 66, Perf: -132.76509786208373
# F1-2D-basic_metaheuristic :: BasicMH 34 of 66, Perf: -101.15176647026584
# F1-2D-basic_metaheuristic :: BasicMH 35 of 66, Perf: -83.5783367223735
# F1-2D-basic_metaheuristic :: BasicMH 36 of 66, Perf: -62.64721063140297
# F1-2D-basic_metaheuristic :: BasicMH 37 of 66, Perf: -450.0
# F1-2D-basic_metaheuristic :: BasicMH 38 of 66, Perf: -450.0
# F1-2D-basic_metaheuristic :: BasicMH 39 of 66, Perf: -450.0
# F1-2D-basic_metaheuristic :: BasicMH 40 of 66, Perf: -449.99998840651034
# F1-2D-basic_metaheuristic :: BasicMH 41 of 66, Perf: -449.9999998436199
# F1-2D-basic_metaheuristic :: BasicMH 42 of 66, Perf: -449.99999997922026
# F1-2D-basic_metaheuristic :: BasicMH 43 of 66, Perf: -449.6146765256378
# F1-2D-basic_metaheuristic :: BasicMH 44 of 66, Perf: -449.1010224532975
# F1-2D-basic_metaheuristic :: BasicMH 45 of 66, Perf: -449.3811912906666
# F1-2D-basic_metaheuristic :: BasicMH 46 of 66, Perf: -448.19234207469424
# F1-2D-basic_metaheuristic :: BasicMH 47 of 66, Perf: -448.9000269615247
# F1-2D-basic_metaheuristic :: BasicMH 48 of 66, Perf: -447.01215631509336
# F1-2D-basic_metaheuristic :: BasicMH 49 of 66, Perf: -425.7617652685546
# F1-2D-basic_metaheuristic :: BasicMH 50 of 66, Perf: -364.300203240398
# F1-2D-basic_metaheuristic :: BasicMH 51 of 66, Perf: -429.5260285557658
# F1-2D-basic_metaheuristic :: BasicMH 52 of 66, Perf: -449.99999998925165
# F1-2D-basic_metaheuristic :: BasicMH 53 of 66, Perf: -449.9999999498777
# F1-2D-basic_metaheuristic :: BasicMH 54 of 66, Perf: -449.99999997263484
# F1-2D-basic_metaheuristic :: BasicMH 55 of 66, Perf: -449.87734687064545
# F1-2D-basic_metaheuristic :: BasicMH 56 of 66, Perf: -449.9999910305842
# F1-2D-basic_metaheuristic :: BasicMH 57 of 66, Perf: -449.99997981212107
# F1-2D-basic_metaheuristic :: BasicMH 58 of 66, Perf: -447.15188528226616
# F1-2D-basic_metaheuristic :: BasicMH 59 of 66, Perf: -449.25674246455924
# F1-2D-basic_metaheuristic :: BasicMH 60 of 66, Perf: -449.41607259109503
# F1-2D-basic_metaheuristic :: BasicMH 61 of 66, Perf: -450.0
# F1-2D-basic_metaheuristic :: BasicMH 62 of 66, Perf: -449.99999999535936
# F1-2D-basic_metaheuristic :: BasicMH 63 of 66, Perf: -449.99999999130995
# F1-2D-basic_metaheuristic :: BasicMH 64 of 66, Perf: -450.0
# F1-2D-basic_metaheuristic :: BasicMH 65 of 66, Perf: -442.21879819891717
# F1-2D-basic_metaheuristic :: BasicMH 66 of 66, Perf: -443.38837877580625
# F1 with bmhs done!
# F1 random_search 2 -441.15853476378345 1.3652445419998003
# F1 central_force_dynamic 2 -449.9925349947022 3.8014509169997837
# F1 central_force_dynamic 2 -449.96574428837033 3.77947070800019
# F1 central_force_dynamic 2 -448.18774519300797 3.7729302910001934
# F1 central_force_dynamic 2 -449.99702266725376 3.856021208999664
# F1 central_force_dynamic 2 -449.9792900000848 3.7335589580002306
# F1 central_force_dynamic 2 -448.7380751434638 3.719523874999595
# F1 central_force_dynamic 2 -449.99849504575815 3.7284131669998715
# F1 central_force_dynamic 2 -449.9770937823502 3.622606375000032
# F1 central_force_dynamic 2 -446.1479053889491 3.655355750000126
# F1 differential_mutation 2 -449.9997829836682 3.0442250000000968
# F1 differential_mutation 2 -449.99657162322734 3.067536291000124
# F1 differential_mutation 2 -446.7810700470935 3.0313507500000014
# F1 differential_mutation 2 -442.52321012410437 3.0488888340000813
# F1 differential_mutation 2 -449.9999954631016 2.992063458999837
# F1 differential_mutation 2 -449.9997395922324 3.02023062499984
# F1 differential_mutation 2 -449.80355003882204 3.049996541999917
# F1 differential_mutation 2 -446.903636073305 3.024523957999918
# F1 firefly_dynamic 2 -446.2738876665126 3.5800141250001616
# F1 firefly_dynamic 2 -449.926460099417 3.6016627080002763
# F1 firefly_dynamic 2 -442.99152202157455 3.580111666999983
# F1 firefly_dynamic 2 -417.3304960581008 3.5985835830001633
# F1 firefly_dynamic 2 -444.9856980129988 3.605000832999849
# F1 firefly_dynamic 2 -440.340189190439 3.612624416000017
# F1 genetic_crossover 2 -435.9372473074683 3.3144087910000053
# F1 genetic_crossover 2 -443.17353560853076 2.7455451249998077
# F1 genetic_crossover 2 -436.1850312472046 2.8014714579999236
# F1 genetic_crossover 2 -437.3437468805509 3.274700665999717
# F1 genetic_crossover 2 -444.8842166906831 2.704164000000219
# F1 genetic_crossover 2 -435.97230598157637 2.7630122499999743
# F1 gravitational_search 2 60.67341133868928 2.9875762500000747
# F1 gravitational_search 2 -21.961594455487784 2.9802729579996594
# F1 gravitational_search 2 -132.76509786208373 2.977568667000014
# F1 gravitational_search 2 -101.15176647026584 2.977249457999733
# F1 gravitational_search 2 -83.5783367223735 2.9778527500002383
# F1 gravitational_search 2 -62.64721063140297 2.9698102090001157
# F1 random_flight 2 -450.0 2.62926487499999
# F1 random_flight 2 -450.0 2.63179375000027
# F1 random_flight 2 -450.0 2.6300077079999937
# F1 random_flight 2 -449.99998840651034 2.635591167000257
# F1 random_flight 2 -449.9999998436199 2.632731374999821
# F1 random_flight 2 -449.99999997922026 2.629935958999795
# F1 local_random_walk 2 -449.6146765256378 1.2873242499999833
# F1 local_random_walk 2 -449.1010224532975 1.3012112080000406
# F1 local_random_walk 2 -449.3811912906666 1.3357551250001052
# F1 local_random_walk 2 -448.19234207469424 1.3023727500003588
# F1 local_random_walk 2 -448.9000269615247 1.302870707999773
# F1 local_random_walk 2 -447.01215631509336 1.3320086250000713
# F1 spiral_dynamic 2 -425.7617652685546 1.6782582920000095
# F1 spiral_dynamic 2 -364.300203240398 1.6802144999996926
# F1 spiral_dynamic 2 -429.5260285557658 1.6828241670000352
# F1 spiral_dynamic 2 -449.99999998925165 1.7027517080000507
# F1 spiral_dynamic 2 -449.9999999498777 1.7021715830001085
# F1 spiral_dynamic 2 -449.99999997263484 1.6959832079996886
# F1 swarm_dynamic 2 -449.87734687064545 1.22503795800003
# F1 swarm_dynamic 2 -449.9999910305842 1.2306143339997107
# F1 swarm_dynamic 2 -449.99997981212107 1.227631792000011
# F1 swarm_dynamic 2 -447.15188528226616 1.2177076670000133
# F1 swarm_dynamic 2 -449.25674246455924 1.225691999999981
# F1 central_force_dynamic 10 32656.346839986658 4.636963958999786
# F1 central_force_dynamic 10 -427.256830297725 4.405472917000225
# F1 central_force_dynamic 10 -374.9375877850419 4.305623208999805
# F1 central_force_dynamic 10 28809.402079901167 4.400340790999962
# F1 central_force_dynamic 10 -443.5021117548584 4.35911891700016
# F1 central_force_dynamic 10 -359.61179381350723 4.279163167000206
# F1 central_force_dynamic 10 27626.615578621255 4.416579540999919
# F1 central_force_dynamic 10 -440.6196371423899 4.330154458999914
# F1 central_force_dynamic 10 -342.8864448610032 4.266253875000075
# F1 differential_mutation 10 7565.03383658838 3.9795943330000227
# F1 differential_mutation 10 11394.244081639405 3.99784795900041
# F1 differential_mutation 10 18119.562009804533 3.9696622090000346
# F1 differential_mutation 10 23251.91044277702 3.9962469160000182
# F1 differential_mutation 10 3192.1909878338033 3.9463059579998117
# F1 differential_mutation 10 6888.66196526235 3.9812444580002193
# F1 differential_mutation 10 14666.046906607811 4.030385166000087
# F1 differential_mutation 10 17955.989181069002 3.9804427499998383
# F1 firefly_dynamic 10 15010.41876024398 4.430845833000149
# F1 firefly_dynamic 10 24370.46288789005 4.4524221249998845
# F1 firefly_dynamic 10 10954.235347976135 4.428053916999943
# F1 firefly_dynamic 10 25876.833100424705 4.399102041999868
# F1 firefly_dynamic 10 13558.557009971913 4.421834457999921
# F1 firefly_dynamic 10 11099.76524790483 4.396194458000082
# F1 genetic_crossover 10 1953.2260766327859 4.256961834000322
# F1 genetic_crossover 10 7991.449590544223 3.846132167000178
# F1 genetic_crossover 10 1814.1467765862235 3.7340320419998534
# F1 genetic_crossover 10 588.1711843048158 4.218967082999825
# F1 genetic_crossover 10 7540.8980709289535 3.796334624999872
# F1 genetic_crossover 10 1513.7969690630782 3.6876317920000474
# F1 gravitational_search 10 26147.711077625914 3.7422280410000894
# F1 gravitational_search 10 26726.553624883643 3.735879125000338
# F1 gravitational_search 10 26007.5962812038 3.7398574159997224
# F1 gravitational_search 10 24303.802479345064 3.7321183330000167
# F1 gravitational_search 10 29645.522997801716 3.7315898340002605
# F1 gravitational_search 10 25752.71478856617 3.7306348339998294
# F1 random_flight 10 -446.8722656909983 3.6121272499999577
# F1 random_flight 10 -446.5650327546782 3.6131310000000667
# F1 random_flight 10 -446.31978600204525 3.6144462910001494
# F1 random_flight 10 -436.8169088692485 3.6141124169998875
# F1 random_flight 10 -442.78622744789214 3.610695959000168
# F1 random_flight 10 -441.10586068390126 3.61937645900025
# F1 local_random_walk 10 82.22132947521098 1.8931483330002266
# F1 local_random_walk 10 1450.8881977447193 1.9466669580001508
# F1 local_random_walk 10 1685.2555034933594 2.0051387920002526
# F1 local_random_walk 10 6676.717335430954 1.8715069999998377
# F1 local_random_walk 10 2200.1148424442317 1.9019064170001911
# F1 local_random_walk 10 1096.9876474487035 1.9512260000001334
# F1 spiral_dynamic 10 5462.566975864223 3.1283360840002388
# F1 spiral_dynamic 10 5199.754956555476 3.164741208999658
# F1 spiral_dynamic 10 5002.895587866569 3.1264848339997116
# F1 spiral_dynamic 10 6013.856474287832 3.1580402499998854
# F1 spiral_dynamic 10 6896.717097013882 3.1401686670001254
# F1 spiral_dynamic 10 7102.8316837527 3.144315749999805
# F1 swarm_dynamic 10 2384.4568025719955 1.7461269159998665
# F1 swarm_dynamic 10 -243.25789642804284 1.7518197919998784
# F1 swarm_dynamic 10 381.1420274026119 1.7462530419998075
# F1 swarm_dynamic 10 5836.269153083029 1.7419675410001219
# F1 swarm_dynamic 10 1676.5050559438068 1.7442899590000707
# F1 swarm_dynamic 10 2620.637523828642 1.7544698749998133
# F1 swarm_dynamic 10 2473.2544232529463 1.8951274169999124
# F1 swarm_dynamic 10 -449.9715277708821 1.7811517499999354
# F1 swarm_dynamic 10 -140.09282023805088 1.7720928749999985
# F1 swarm_dynamic 10 -449.99999941523674 1.8472510410001632
# F1 swarm_dynamic 10 6539.569689331899 1.7486593749999884
# F1 swarm_dynamic 10 6495.690263726654 1.7503274579999015
# F1-30D-basic_metaheuristic :: BasicMH 1 of 66, Perf: 60866.856695914306
# F1-30D-basic_metaheuristic :: BasicMH 2 of 66, Perf: 136720.71480277984
# F1-30D-basic_metaheuristic :: BasicMH 3 of 66, Perf: 73694.91170097329
# F1-30D-basic_metaheuristic :: BasicMH 4 of 66, Perf: 44026.73593746276
# F1-30D-basic_metaheuristic :: BasicMH 5 of 66, Perf: 140460.22355395753
# F1-30D-basic_metaheuristic :: BasicMH 6 of 66, Perf: 59345.638656269904
# F1-30D-basic_metaheuristic :: BasicMH 7 of 66, Perf: 36007.717702467315
# F1-30D-basic_metaheuristic :: BasicMH 8 of 66, Perf: 136808.41568294604
# F1-30D-basic_metaheuristic :: BasicMH 9 of 66, Perf: 52315.872119378306
# F1-30D-basic_metaheuristic :: BasicMH 10 of 66, Perf: 27101.39055373424
# F1-30D-basic_metaheuristic :: BasicMH 11 of 66, Perf: 108542.31127205786
# F1-30D-basic_metaheuristic :: BasicMH 12 of 66, Perf: 122265.15621424558
# F1-30D-basic_metaheuristic :: BasicMH 13 of 66, Perf: 137438.50674403156
# F1-30D-basic_metaheuristic :: BasicMH 14 of 66, Perf: 141052.75627548917
# F1-30D-basic_metaheuristic :: BasicMH 15 of 66, Perf: 86092.41777655095
# F1-30D-basic_metaheuristic :: BasicMH 16 of 66, Perf: 107903.83687391032
# F1-30D-basic_metaheuristic :: BasicMH 17 of 66, Perf: 133307.76245061355
# F1-30D-basic_metaheuristic :: BasicMH 18 of 66, Perf: 130394.92096307084
# F1-30D-basic_metaheuristic :: BasicMH 19 of 66, Perf: 101321.94754687697
# F1-30D-basic_metaheuristic :: BasicMH 20 of 66, Perf: 120424.19472318723
# F1-30D-basic_metaheuristic :: BasicMH 21 of 66, Perf: 109590.19791604234
# F1-30D-basic_metaheuristic :: BasicMH 22 of 66, Perf: 116685.00193343201
# F1-30D-basic_metaheuristic :: BasicMH 23 of 66, Perf: 100554.47902523285
# F1-30D-basic_metaheuristic :: BasicMH 24 of 66, Perf: 103357.40205170712
# F1-30D-basic_metaheuristic :: BasicMH 25 of 66, Perf: 40869.97923386695
# F1-30D-basic_metaheuristic :: BasicMH 62 of 66, Perf: 153.19132132349569
# F1-30D-basic_metaheuristic :: BasicMH 63 of 66, Perf: 6378.397297373535
# F1-30D-basic_metaheuristic :: BasicMH 64 of 66, Perf: 4626.4475340198715
# F1-30D-basic_metaheuristic :: BasicMH 65 of 66, Perf: 49930.25364282851
# F1-30D-basic_metaheuristic :: BasicMH 66 of 66, Perf: 55913.08962615838
# F1 with bmhs done!
# F1 random_search 30 60866.856695914306 3.1192513340001824
# F1 central_force_dynamic 30 136720.71480277984 5.856862541999817
# F1 central_force_dynamic 30 73694.91170097329 5.8830878329999905
# F1 central_force_dynamic 30 44026.73593746276 5.774300000000039
# F1 central_force_dynamic 30 140460.22355395753 5.857824208999773
# F1 central_force_dynamic 30 59345.638656269904 5.860803625000244
# F1 central_force_dynamic 30 36007.717702467315 5.772855708999941
# F1 central_force_dynamic 30 136808.41568294604 5.882671834000121
# F1 central_force_dynamic 30 52315.872119378306 6.074405040999864
# F1 central_force_dynamic 30 27101.39055373424 5.785671999999977
# F1 differential_mutation 30 108542.31127205786 6.225130125000305
# F1 differential_mutation 30 122265.15621424558 6.246839750000163
# F1 differential_mutation 30 137438.50674403156 6.2652805829998215
# F1 differential_mutation 30 141052.75627548917 6.275707124999826
# F1 differential_mutation 30 86092.41777655095 6.214405833000001
# F1 differential_mutation 30 107903.83687391032 6.232174541999939
# F1 differential_mutation 30 133307.76245061355 6.227581874999942
# F1 differential_mutation 30 130394.92096307084 6.279158125000322
# F1 firefly_dynamic 30 101321.94754687697 6.261325791999752
# F1 firefly_dynamic 30 120424.19472318723 6.263664541000253
# F1 firefly_dynamic 30 109590.19791604234 6.254193583000415
# F1 firefly_dynamic 30 116685.00193343201 6.249610750000102
# F1 firefly_dynamic 30 100554.47902523285 6.2682557919997635
# F1 firefly_dynamic 30 103357.40205170712 6.2481510000002345
# F1 genetic_crossover 30 40869.97923386695 7.867939041999762
# F1 genetic_crossover 30 77995.87374143756 7.440511082999819
# F1 genetic_crossover 30 45957.786748286024 7.323495749999893
# F1 genetic_crossover 30 35839.13256995886 7.846056166999915
# F1 genetic_crossover 30 74306.62609012226 7.418620208999982
# F1 genetic_crossover 30 39638.283887103506 7.2937096670002575
# F1 gravitational_search 30 93962.27756172809 5.458110083000065
# F1 gravitational_search 30 101251.87759147535 5.441660542000136
# F1 gravitational_search 30 97053.26607558422 5.446584333999908
# F1 gravitational_search 30 93085.47356328146 5.449090417000207
# F1 gravitational_search 30 98860.26401217512 5.445870041000035
# F1 gravitational_search 30 101835.02885404536 5.460591666000255
# F1 random_flight 30 7206.600365131135 5.941232583999863
# F1 random_flight 30 6654.579119085708 5.953643125000326
# F1 random_flight 30 6238.257437577634 5.951101333000224
# F1 random_flight 30 3532.251409438877 5.938468040999851
# F1 random_flight 30 3300.9991811554337 5.945232915999895
# F1 random_flight 30 3981.816792441074 5.972085042000344
# F1 local_random_walk 30 19221.5559290713 3.156600165999862
# F1 local_random_walk 30 55265.03843672876 3.201173375000053
# F1 local_random_walk 30 54635.80647957113 3.345674458999838
# F1 local_random_walk 30 65172.134757848034 3.09676779099982
# F1 local_random_walk 30 36531.807072242365 3.1878948749999836
# F1 local_random_walk 30 29231.993941467415 3.308455374999994
# F1 spiral_dynamic 30 49325.72161936636 15.561830124999688
# F1 spiral_dynamic 30 46472.97675311139 15.58145850000028
# F1 spiral_dynamic 30 53477.83018860138 15.554528083999685
# F1 spiral_dynamic 30 50555.66937085027 15.552568000000065
# F1 spiral_dynamic 30 41288.52234584828 15.524599750000107
# F1 spiral_dynamic 30 48157.961091067686 15.548046584000076
# F1 swarm_dynamic 30 45037.92331457724 2.937648666000314
# F1 swarm_dynamic 30 10540.776749834775 2.9444049999997333
# F1 swarm_dynamic 30 20891.87615210787 2.9423907919999692
# F1 swarm_dynamic 30 51823.03825817164 2.9337314169997626
# F1 swarm_dynamic 30 32275.753217061887 2.9389362909996635
# F1 swarm_dynamic 30 39284.55168868271 2.938719250000304
# F1 swarm_dynamic 30 57299.261259514766 3.0850057920001746
# F1 swarm_dynamic 30 153.19132132349569 2.991936832999727
# F1 swarm_dynamic 30 6378.397297373535 2.970817958000225
# F1 swarm_dynamic 30 4626.4475340198715 3.0751232919997165
# F1 swarm_dynamic 30 49930.25364282851 2.9606286250000267
# F1 swarm_dynamic 30 55913.08962615838 2.9493952920001902
# F1-50D-basic_metaheuristic :: BasicMH 1 of 66, Perf: 143813.21227353817
# F1-50D-basic_metaheuristic :: BasicMH 2 of 66, Perf: 243284.65664601672
# F1-50D-basic_metaheuristic :: BasicMH 3 of 66, Perf: 163108.57389433868
# F1-50D-basic_metaheuristic :: BasicMH 4 of 66, Perf: 111663.08070221983
# F1-50D-basic_metaheuristic :: BasicMH 5 of 66, Perf: 243486.25481856553
# F1-50D-basic_metaheuristic :: BasicMH 6 of 66, Perf: 135824.37359093886
# F1-50D-basic_metaheuristic :: BasicMH 7 of 66, Perf: 107946.84417969594
# F1-50D-basic_metaheuristic :: BasicMH 8 of 66, Perf: 252836.31521546718
# F1-50D-basic_metaheuristic :: BasicMH 9 of 66, Perf: 119245.54110904122
# F1-50D-basic_metaheuristic :: BasicMH 10 of 66, Perf: 95560.08957775605
# F1-50D-basic_metaheuristic :: BasicMH 11 of 66, Perf: 253699.8443837209
# F1-50D-basic_metaheuristic :: BasicMH 12 of 66, Perf: 233550.05314062798
# F1-50D-basic_metaheuristic :: BasicMH 13 of 66, Perf: 243085.82558402544
# F1-50D-basic_metaheuristic :: BasicMH 14 of 66, Perf: 241836.00072184656
# F1-50D-basic_metaheuristic :: BasicMH 15 of 66, Perf: 201544.43752347166
# F1-50D-basic_metaheuristic :: BasicMH 16 of 66, Perf: 231196.79264864727
# F1-50D-basic_metaheuristic :: BasicMH 17 of 66, Perf: 242314.82117166067
# F1-50D-basic_metaheuristic :: BasicMH 18 of 66, Perf: 243844.84026824427
# F1-50D-basic_metaheuristic :: BasicMH 19 of 66, Perf: 201284.71330696213
# F1-50D-basic_metaheuristic :: BasicMH 20 of 66, Perf: 227086.540036197
# F1-50D-basic_metaheuristic :: BasicMH 57 of 66, Perf: 64457.30609767498
# F1-50D-basic_metaheuristic :: BasicMH 58 of 66, Perf: 113515.8832202777
# F1-50D-basic_metaheuristic :: BasicMH 59 of 66, Perf: 80844.8473580053
# F1-50D-basic_metaheuristic :: BasicMH 60 of 66, Perf: 83007.91066438047
# F1-50D-basic_metaheuristic :: BasicMH 61 of 66, Perf: 115038.68026570835
# F1-50D-basic_metaheuristic :: BasicMH 62 of 66, Perf: 4479.332883282983
# F1-50D-basic_metaheuristic :: BasicMH 63 of 66, Perf: 25255.31598039934
# F1-50D-basic_metaheuristic :: BasicMH 64 of 66, Perf: 35785.39550994107
# F1-50D-basic_metaheuristic :: BasicMH 65 of 66, Perf: 161311.74113389303
# F1-50D-basic_metaheuristic :: BasicMH 66 of 66, Perf: 128400.60624502183
# F1 with bmhs done!
# F1 random_search 50 143813.21227353817 4.2998863749999146
# F1 central_force_dynamic 50 243284.65664601672 7.282206458000019
# F1 central_force_dynamic 50 163108.57389433868 7.2889134580000245
# F1 central_force_dynamic 50 111663.08070221983 7.189283791999969
# F1 central_force_dynamic 50 243486.25481856553 7.276852082999994
# F1 central_force_dynamic 50 135824.37359093886 7.278559374999986
# F1 central_force_dynamic 50 107946.84417969594 7.18764129200008
# F1 central_force_dynamic 50 252836.31521546718 7.269908125000256
# F1 central_force_dynamic 50 119245.54110904122 7.500178958000106
# F1 central_force_dynamic 50 95560.08957775605 7.210579500000222
# F1 differential_mutation 50 253699.8443837209 8.476212582999779
# F1 differential_mutation 50 233550.05314062798 8.514967874999911
# F1 differential_mutation 50 243085.82558402544 8.487930750000032
# F1 differential_mutation 50 241836.00072184656 8.538753959000132
# F1 differential_mutation 50 201544.43752347166 8.439318000000185
# F1 differential_mutation 50 231196.79264864727 8.483241500000076
# F1 differential_mutation 50 242314.82117166067 8.45477287499989
# F1 differential_mutation 50 243844.84026824427 8.497270500000013
# F1 firefly_dynamic 50 201284.71330696213 8.029989249999744
# F1 firefly_dynamic 50 227086.540036197 8.027689957999883
# F1 firefly_dynamic 50 203796.52505888892 8.02551187500012
# F1 firefly_dynamic 50 220371.54900447314 8.016118167000059
# F1 firefly_dynamic 50 214913.67071168858 8.021017916999881
# F1 firefly_dynamic 50 210060.0819750788 8.027752208000038
# F1 genetic_crossover 50 109624.14393852564 13.713020165999751
# F1 genetic_crossover 50 171805.26737212157 13.27732237500004
# F1 genetic_crossover 50 116962.04852235595 13.214848167000127
# F1 genetic_crossover 50 97926.45191067144 13.65091137499985
# F1 genetic_crossover 50 161564.1871803261 13.25326700000005
# F1 genetic_crossover 50 102533.57411174774 13.105154500000026
# F1 gravitational_search 50 162401.57681745008 7.110467625000183
# F1 gravitational_search 50 163433.4819313662 7.095274000000245
# F1 gravitational_search 50 169805.7480205658 7.096624625000004
# F1 gravitational_search 50 167370.69132127796 7.1056372500002
# F1 gravitational_search 50 159104.93573227437 7.121349874999851
# F1 gravitational_search 50 166590.1875103031 7.117720792
# F1 random_flight 50 40853.412426879855 8.256776999999602
# F1 random_flight 50 35114.28452942333 8.268343834000007
# F1 random_flight 50 31541.8339337568 8.26544904100001
# F1 random_flight 50 23401.791938591505 8.229701666999972
# F1 random_flight 50 23908.068808917953 8.241698999999699
# F1 random_flight 50 21040.923693962603 8.233101875000102
# F1 local_random_walk 50 70807.79085382693 4.408234832999824
# F1 local_random_walk 50 171265.457853278 4.433534333999887
# F1 local_random_walk 50 145688.8719425422 4.657951582999885
# F1 local_random_walk 50 136634.2881950417 4.300495124999998
# F1 local_random_walk 50 100023.38482192632 4.375915417000215
# F1 local_random_walk 50 83910.2349713362 4.610112916000162
# F1 spiral_dynamic 50 114385.99658029797 62.58900095800027
# F1 spiral_dynamic 50 98589.70651266766 56.05191379200005
# F1 spiral_dynamic 50 100949.66170864637 53.27887425000017
# F1 spiral_dynamic 50 115186.38425189187 53.072611125000094
# F1 spiral_dynamic 50 107976.15025579253 53.394617791999735
# F1 spiral_dynamic 50 118851.61528222372 53.20964387499998
# F1 swarm_dynamic 50 108869.90285104913 3.484728958999767
# F1 swarm_dynamic 50 47950.63806150439 3.503896708999946
# F1 swarm_dynamic 50 64457.30609767498 3.483654082999692
# F1 swarm_dynamic 50 113515.8832202777 3.490397500000199
# F1 swarm_dynamic 50 80844.8473580053 3.494193667000218
# F1 swarm_dynamic 50 83007.91066438047 3.486987541000417
# F1 swarm_dynamic 50 115038.68026570835 3.6039902500001517
# F1 swarm_dynamic 50 4479.332883282983 3.5493088749999515
# F1 swarm_dynamic 50 25255.31598039934 3.5296117090001644
# F1 swarm_dynamic 50 35785.39550994107 3.601369208000051
# F1 swarm_dynamic 50 161311.74113389303 3.501221749999786
# F1 swarm_dynamic 50 128400.60624502183 3.4981520840001394
# F2-2D-basic_metaheuristic :: BasicMH 1 of 66, Perf: -442.93582843202563
# F2-2D-basic_metaheuristic :: BasicMH 2 of 66, Perf: -449.83330098491797
# F2-2D-basic_metaheuristic :: BasicMH 3 of 66, Perf: -449.98435143351827
# F2-2D-basic_metaheuristic :: BasicMH 4 of 66, Perf: -449.4136095488759
# F2-2D-basic_metaheuristic :: BasicMH 5 of 66, Perf: -449.99630218291736
# F2-2D-basic_metaheuristic :: BasicMH 6 of 66, Perf: -449.98428583665816
# F2-2D-basic_metaheuristic :: BasicMH 7 of 66, Perf: -447.6868211219818
# F2-2D-basic_metaheuristic :: BasicMH 8 of 66, Perf: -449.9983660834206
# F2-2D-basic_metaheuristic :: BasicMH 9 of 66, Perf: -449.9819498506294
# F2-2D-basic_metaheuristic :: BasicMH 10 of 66, Perf: -444.992328010129
# F2-2D-basic_metaheuristic :: BasicMH 11 of 66, Perf: -449.99993336897614
# F2-2D-basic_metaheuristic :: BasicMH 12 of 66, Perf: -449.99868985689847
# F2-2D-basic_metaheuristic :: BasicMH 13 of 66, Perf: -448.6417889924949
# F2-2D-basic_metaheuristic :: BasicMH 14 of 66, Perf: -448.240029372855
# F2-2D-basic_metaheuristic :: BasicMH 15 of 66, Perf: -449.9999963123737
# F2-2D-basic_metaheuristic :: BasicMH 16 of 66, Perf: -449.9998692573059
# F2-2D-basic_metaheuristic :: BasicMH 17 of 66, Perf: -449.8921074074421
# F2-2D-basic_metaheuristic :: BasicMH 18 of 66, Perf: -449.41693470496705
# F2-2D-basic_metaheuristic :: BasicMH 19 of 66, Perf: -442.54236836823964
# F2-2D-basic_metaheuristic :: BasicMH 20 of 66, Perf: -449.875342952875
# F2-2D-basic_metaheuristic :: BasicMH 21 of 66, Perf: -443.6415796555756
# F2-2D-basic_metaheuristic :: BasicMH 22 of 66, Perf: -395.08363253244784
# F2-2D-basic_metaheuristic :: BasicMH 23 of 66, Perf: -444.4688545064841
# F2-2D-basic_metaheuristic :: BasicMH 24 of 66, Perf: -437.80126881037734
# F2-2D-basic_metaheuristic :: BasicMH 25 of 66, Perf: -434.447245551469
# F2-2D-basic_metaheuristic :: BasicMH 26 of 66, Perf: -443.68927344852165
# F2-2D-basic_metaheuristic :: BasicMH 27 of 66, Perf: -437.88382905168913
# F2-2D-basic_metaheuristic :: BasicMH 28 of 66, Perf: -432.3772292089755
# F2-2D-basic_metaheuristic :: BasicMH 29 of 66, Perf: -443.8887685649227
# F2-2D-basic_metaheuristic :: BasicMH 30 of 66, Perf: -437.29311346262404
# F2-2D-basic_metaheuristic :: BasicMH 31 of 66, Perf: 306.6030485273791
# F2-2D-basic_metaheuristic :: BasicMH 32 of 66, Perf: 251.60799816209595
# F2-2D-basic_metaheuristic :: BasicMH 33 of 66, Perf: 487.87918084781325
# F2-2D-basic_metaheuristic :: BasicMH 34 of 66, Perf: 202.90528806906505
# F2-2D-basic_metaheuristic :: BasicMH 35 of 66, Perf: 458.02471947426477
# F2-2D-basic_metaheuristic :: BasicMH 36 of 66, Perf: 444.6591533177032
# F2-2D-basic_metaheuristic :: BasicMH 37 of 66, Perf: -449.99999999842345
# F2-2D-basic_metaheuristic :: BasicMH 38 of 66, Perf: -449.99999999995026
# F2-2D-basic_metaheuristic :: BasicMH 39 of 66, Perf: -449.99999999999824
# F2-2D-basic_metaheuristic :: BasicMH 40 of 66, Perf: -449.9924198114014
# F2-2D-basic_metaheuristic :: BasicMH 41 of 66, Perf: -449.9999406830805
# F2-2D-basic_metaheuristic :: BasicMH 42 of 66, Perf: -449.99999960286317
# F2-2D-basic_metaheuristic :: BasicMH 43 of 66, Perf: -449.4415635414324
# F2-2D-basic_metaheuristic :: BasicMH 44 of 66, Perf: -448.9128322713581
# F2-2D-basic_metaheuristic :: BasicMH 45 of 66, Perf: -448.90179582941596
# F2-2D-basic_metaheuristic :: BasicMH 46 of 66, Perf: -445.7579767789402
# F2-2D-basic_metaheuristic :: BasicMH 47 of 66, Perf: -447.6398271283445
# F2-2D-basic_metaheuristic :: BasicMH 48 of 66, Perf: -448.348979064564
# F2-2D-basic_metaheuristic :: BasicMH 49 of 66, Perf: -297.8769998123971
# F2-2D-basic_metaheuristic :: BasicMH 50 of 66, Perf: -396.9273140001615
# F2-2D-basic_metaheuristic :: BasicMH 51 of 66, Perf: -353.9781325056383
# F2-2D-basic_metaheuristic :: BasicMH 52 of 66, Perf: -449.99999999479536
# F2-2D-basic_metaheuristic :: BasicMH 53 of 66, Perf: -449.999999992059
# F2-2D-basic_metaheuristic :: BasicMH 54 of 66, Perf: -449.99999999384937
# F2-2D-basic_metaheuristic :: BasicMH 55 of 66, Perf: -449.9183702852611
# F2-2D-basic_metaheuristic :: BasicMH 56 of 66, Perf: -449.9999935170806
# F2-2D-basic_metaheuristic :: BasicMH 57 of 66, Perf: -449.999983422608
# F2-2D-basic_metaheuristic :: BasicMH 58 of 66, Perf: -448.6065402783758
# F2-2D-basic_metaheuristic :: BasicMH 59 of 66, Perf: -449.77830120608036
# F2-2D-basic_metaheuristic :: BasicMH 60 of 66, Perf: -449.6243860168563
# F2-2D-basic_metaheuristic :: BasicMH 61 of 66, Perf: -450.0
# F2-2D-basic_metaheuristic :: BasicMH 62 of 66, Perf: -449.99999999502796
# F2-2D-basic_metaheuristic :: BasicMH 63 of 66, Perf: -449.9999999906988
# F2-2D-basic_metaheuristic :: BasicMH 64 of 66, Perf: -450.0
# F2-2D-basic_metaheuristic :: BasicMH 65 of 66, Perf: -446.5276017725122
# F2-2D-basic_metaheuristic :: BasicMH 66 of 66, Perf: -447.19167788573384
# F2 with bmhs done!
# F2 random_search 2 -442.93582843202563 1.3809455830000843
# F2 central_force_dynamic 2 -449.83330098491797 3.143425707999995
# F2 central_force_dynamic 2 -449.98435143351827 3.045025542000076
# F2 central_force_dynamic 2 -449.4136095488759 3.0512447500000235
# F2 central_force_dynamic 2 -449.99630218291736 3.127681083000425
# F2 central_force_dynamic 2 -449.98428583665816 3.0568102080001154
# F2 central_force_dynamic 2 -447.6868211219818 3.0487289579996286
# F2 central_force_dynamic 2 -449.9983660834206 3.100530582999909
# F2 central_force_dynamic 2 -449.9819498506294 3.0337350830000105
# F2 central_force_dynamic 2 -444.992328010129 3.047600583000076
# F2 differential_mutation 2 -449.99993336897614 2.507719624999936
# F2 differential_mutation 2 -449.99868985689847 2.5258558330001506
# F2 differential_mutation 2 -448.6417889924949 2.510792499999752
# F2 differential_mutation 2 -448.240029372855 2.6065438750001704
# F2 differential_mutation 2 -449.9999963123737 2.5046020419999877
# F2 differential_mutation 2 -449.9998692573059 2.524271041999782
# F2 differential_mutation 2 -449.8921074074421 2.5077941670001564
# F2 differential_mutation 2 -449.41693470496705 2.5324945829997887
# F2 firefly_dynamic 2 -442.54236836823964 2.9913675410002725
# F2 firefly_dynamic 2 -449.875342952875 3.0322548749995804
# F2 firefly_dynamic 2 -443.6415796555756 3.070207332999871
# F2 firefly_dynamic 2 -395.08363253244784 3.0107527500003926
# F2 firefly_dynamic 2 -444.4688545064841 3.0420418329999848
# F2 firefly_dynamic 2 -437.80126881037734 3.010770459000014
# F2 genetic_crossover 2 -434.447245551469 3.2356754170000386
# F2 genetic_crossover 2 -443.68927344852165 2.3366834169996764
# F2 genetic_crossover 2 -437.88382905168913 2.3519138329997986
# F2 genetic_crossover 2 -432.3772292089755 2.844727540999884
# F2 genetic_crossover 2 -443.8887685649227 2.3406873330000053
# F2 genetic_crossover 2 -437.29311346262404 2.3627939590001006
# F2 gravitational_search 2 306.6030485273791 2.4907456250002724
# F2 gravitational_search 2 251.60799816209595 2.4809067920000416
# F2 gravitational_search 2 487.87918084781325 2.475449624999783
# F2 gravitational_search 2 202.90528806906505 2.483087584000259
# F2 gravitational_search 2 458.02471947426477 2.481035041999803
# F2 gravitational_search 2 444.6591533177032 2.4909148750002714
# F2 random_flight 2 -449.99999999842345 2.277802458000224
# F2 random_flight 2 -449.99999999995026 2.2416337499998917
# F2 random_flight 2 -449.99999999999824 2.217123208999965
# F2 random_flight 2 -449.9924198114014 2.2125748329999624
# F2 random_flight 2 -449.9999406830805 2.2160811250000734
# F2 random_flight 2 -449.99999960286317 2.2331624580001517
# F2 local_random_walk 2 -449.4415635414324 1.1001096249997317
# F2 local_random_walk 2 -448.9128322713581 1.104798832999677
# F2 local_random_walk 2 -448.90179582941596 1.1444559579999805
# F2 local_random_walk 2 -445.7579767789402 1.100856415999715
# F2 local_random_walk 2 -447.6398271283445 1.0988980829997672
# F2 local_random_walk 2 -448.348979064564 1.1210201250000864
# F2 spiral_dynamic 2 -297.8769998123971 1.4191706249998788
# F2 spiral_dynamic 2 -396.9273140001615 1.4177684589999444
# F2 spiral_dynamic 2 -353.9781325056383 1.4094952499999636
# F2 spiral_dynamic 2 -449.99999999479536 1.3925364169999739
# F2 spiral_dynamic 2 -449.999999992059 1.419843082999705
# F2 spiral_dynamic 2 -449.99999999384937 1.3973545830003786
# F2 swarm_dynamic 2 -449.9183702852611 1.0416900000000169
# F2 swarm_dynamic 2 -449.9999935170806 1.0560951659999773
# F2 swarm_dynamic 2 -449.999983422608 1.0420997920000445
# F2 swarm_dynamic 2 -448.6065402783758 1.0464573330000349
# F2 swarm_dynamic 2 -449.77830120608036 1.0285562089998166
# F2 swarm_dynamic 2 -449.6243860168563 1.0416898749999746
# F2 swarm_dynamic 2 -450.0 1.139240874999814
# F2 swarm_dynamic 2 -449.99999999502796 1.0511288339998828
# F2 swarm_dynamic 2 -449.9999999906988 1.0444101670000236
# F2 swarm_dynamic 2 -450.0 1.072200334000172
# F2 swarm_dynamic 2 -446.5276017725122 1.05326979199981
# F2 swarm_dynamic 2 -447.19167788573384 1.0439834170001632
# F2-10D-basic_metaheuristic :: BasicMH 1 of 66, Perf: 7726.7156723480475
# F2-10D-basic_metaheuristic :: BasicMH 2 of 66, Perf: 43570.414541770806
# F2-10D-basic_metaheuristic :: BasicMH 3 of 66, Perf: 390.7078768747218
# F2-10D-basic_metaheuristic :: BasicMH 4 of 66, Perf: -306.26118699471647
# F2-10D-basic_metaheuristic :: BasicMH 5 of 66, Perf: 45311.439983086035
# F2-10D-basic_metaheuristic :: BasicMH 6 of 66, Perf: -295.1096037392509
# F2-10D-basic_metaheuristic :: BasicMH 7 of 66, Perf: -258.1639667856497
# F2-10D-basic_metaheuristic :: BasicMH 8 of 66, Perf: 41537.60761541894
# F2-10D-basic_metaheuristic :: BasicMH 9 of 66, Perf: -388.2258277632486
# F2-10D-basic_metaheuristic :: BasicMH 46 of 66, Perf: 8105.740353471613
# F2-10D-basic_metaheuristic :: BasicMH 47 of 66, Perf: 5473.556732150355
# F2-10D-basic_metaheuristic :: BasicMH 48 of 66, Perf: 5992.44113082446
# F2-10D-basic_metaheuristic :: BasicMH 49 of 66, Perf: 7657.492022041524
# F2-10D-basic_metaheuristic :: BasicMH 50 of 66, Perf: 4710.337163163928
# F2-10D-basic_metaheuristic :: BasicMH 51 of 66, Perf: 8683.857208520494
# F2-10D-basic_metaheuristic :: BasicMH 52 of 66, Perf: 7333.346081884632
# F2-10D-basic_metaheuristic :: BasicMH 53 of 66, Perf: 8599.411858148038
# F2-10D-basic_metaheuristic :: BasicMH 54 of 66, Perf: 9134.579101070274
# F2-10D-basic_metaheuristic :: BasicMH 55 of 66, Perf: 3658.5727961486073
# F2-10D-basic_metaheuristic :: BasicMH 56 of 66, Perf: 211.12963036732043
# F2-10D-basic_metaheuristic :: BasicMH 57 of 66, Perf: 342.26882548576447
# F2-10D-basic_metaheuristic :: BasicMH 58 of 66, Perf: 5454.149437772785
# ...
# F14-30D-basic_metaheuristic :: BasicMH 29 of 66, Perf: -285.73235595534663
# F14-30D-basic_metaheuristic :: BasicMH 30 of 66, Perf: -285.8048797261343
# F14-30D-basic_metaheuristic :: BasicMH 31 of 66, Perf: -285.5786746631885
# F14-30D-basic_metaheuristic :: BasicMH 32 of 66, Perf: -285.47326135123006
# F14-30D-basic_metaheuristic :: BasicMH 33 of 66, Perf: -285.5123736837769
# F14-30D-basic_metaheuristic :: BasicMH 34 of 66, Perf: -285.57386035470466
# F14-30D-basic_metaheuristic :: BasicMH 35 of 66, Perf: -285.55383004351415
# F14-30D-basic_metaheuristic :: BasicMH 36 of 66, Perf: -285.5917145472173
# F14-30D-basic_metaheuristic :: BasicMH 37 of 66, Perf: -285.8911521268133
# F14-30D-basic_metaheuristic :: BasicMH 38 of 66, Perf: -285.8207082836169
# F14-30D-basic_metaheuristic :: BasicMH 39 of 66, Perf: -285.8212519634214
# F14-30D-basic_metaheuristic :: BasicMH 40 of 66, Perf: -285.99109637009815
# F14-30D-basic_metaheuristic :: BasicMH 41 of 66, Perf: -285.99185722630205
# F14-30D-basic_metaheuristic :: BasicMH 42 of 66, Perf: -285.9680855655589
# F14-30D-basic_metaheuristic :: BasicMH 43 of 66, Perf: -285.7074955283873
# F14-30D-basic_metaheuristic :: BasicMH 44 of 66, Perf: -285.6242135811096
# F14-30D-basic_metaheuristic :: BasicMH 45 of 66, Perf: -285.58618573322195
# F14-30D-basic_metaheuristic :: BasicMH 46 of 66, Perf: -285.6817132175697
# F14-30D-basic_metaheuristic :: BasicMH 47 of 66, Perf: -285.7322677022934
# F14-30D-basic_metaheuristic :: BasicMH 48 of 66, Perf: -285.67774554348665
# F14-30D-basic_metaheuristic :: BasicMH 49 of 66, Perf: -285.5670227459967
# F14-30D-basic_metaheuristic :: BasicMH 50 of 66, Perf: -285.70508948460207
# F14-30D-basic_metaheuristic :: BasicMH 51 of 66, Perf: -285.73906800570455
# F14-30D-basic_metaheuristic :: BasicMH 52 of 66, Perf: -285.49723979646024
# F14-30D-basic_metaheuristic :: BasicMH 53 of 66, Perf: -285.8059600591342
# F14-30D-basic_metaheuristic :: BasicMH 54 of 66, Perf: -285.77714858580805
# F14-30D-basic_metaheuristic :: BasicMH 55 of 66, Perf: -285.68955834766007
# F14-30D-basic_metaheuristic :: BasicMH 56 of 66, Perf: -285.70689827904505
# F14-30D-basic_metaheuristic :: BasicMH 57 of 66, Perf: -285.7960059059672
# F14-30D-basic_metaheuristic :: BasicMH 58 of 66, Perf: -285.6287792534801
# F14-30D-basic_metaheuristic :: BasicMH 59 of 66, Perf: -285.82605456892674
# F14-30D-basic_metaheuristic :: BasicMH 60 of 66, Perf: -285.6726113310599
# F14-30D-basic_metaheuristic :: BasicMH 61 of 66, Perf: -285.9734272102086
# F14-30D-basic_metaheuristic :: BasicMH 62 of 66, Perf: -286.00485249097216
# F14-30D-basic_metaheuristic :: BasicMH 63 of 66, Perf: -285.84476146928006
# F14-30D-basic_metaheuristic :: BasicMH 64 of 66, Perf: -286.08812319733323
# F14-30D-basic_metaheuristic :: BasicMH 65 of 66, Perf: -285.7200365248342
# F14-30D-basic_metaheuristic :: BasicMH 66 of 66, Perf: -285.6673588301973
# F14 with bmhs done!
# F14 random_search 30 -285.70660326824265 4.983274750000419
# F14 central_force_dynamic 30 -285.32089156936 7.179213499999605
# F14 central_force_dynamic 30 -285.70045056691157 7.155358249998244
# F14 central_force_dynamic 30 -285.8283909440003 7.145384332998219
# F14 central_force_dynamic 30 -285.3302265877886 7.19743683300112
# F14 central_force_dynamic 30 -285.84346211998934 7.160566916001699
# F14 central_force_dynamic 30 -286.1310908434305 7.571708374998707
# F14 central_force_dynamic 30 -285.3065012195846 7.266679374999512
# F14 central_force_dynamic 30 -285.7350053952605 7.182982082998933
# F14 central_force_dynamic 30 -286.03734486409724 7.173937249997834
# F14 differential_mutation 30 -285.7082800289029 9.900861583002552
# F14 differential_mutation 30 -285.67338881484136 9.91467054199893
# F14 differential_mutation 30 -285.6300561418538 9.886754458002542
# F14 differential_mutation 30 -285.64418809039756 9.915062709002086
# F14 differential_mutation 30 -285.6679947347185 9.841916583998682
# F14 differential_mutation 30 -285.6607371338543 9.877143541001715
# F14 differential_mutation 30 -285.59598541206395 9.857290957999794
# F14 differential_mutation 30 -285.60109345272724 9.873647917000199
# F14 firefly_dynamic 30 -285.73818467225715 7.6065372080011
# F14 firefly_dynamic 30 -285.754963675232 7.613045666999824
# F14 firefly_dynamic 30 -285.76986192862796 7.613986374999513
# F14 firefly_dynamic 30 -285.76098040050397 7.597367083999416
# F14 firefly_dynamic 30 -285.7894232193107 7.6186394579999615
# F14 firefly_dynamic 30 -285.73664915678626 7.616346792001423
# F14 genetic_crossover 30 -285.7390195827947 11.289225249998708
# F14 genetic_crossover 30 -285.8363215337572 10.936235082997882
# F14 genetic_crossover 30 -285.7323011823806 10.898864667000453
# F14 genetic_crossover 30 -285.75814832090373 11.245192791997397
# F14 genetic_crossover 30 -285.73235595534663 10.896209915998043
# F14 genetic_crossover 30 -285.8048797261343 10.780446208002104
# F14 gravitational_search 30 -285.5786746631885 6.8893714170008025
# F14 gravitational_search 30 -285.47326135123006 6.89129766699989
# F14 gravitational_search 30 -285.5123736837769 6.891140000003361
# F14 gravitational_search 30 -285.57386035470466 6.898035875001369
# F14 gravitational_search 30 -285.55383004351415 6.885028125001554
# F14 gravitational_search 30 -285.5917145472173 6.890472167000553
# F14 random_flight 30 -285.8911521268133 9.58517666699845
# F14 random_flight 30 -285.8207082836169 9.584916957999667
# F14 random_flight 30 -285.8212519634214 9.587772082999436
# F14 random_flight 30 -285.99109637009815 9.579426459000388
# F14 random_flight 30 -285.99185722630205 9.62582216699957
# F14 random_flight 30 -285.9680855655589 9.602974166999047
# F14 local_random_walk 30 -285.7074955283873 4.817627374999574
# F14 local_random_walk 30 -285.6242135811096 4.841267750001862
# F14 local_random_walk 30 -285.58618573322195 4.970105540996883
# F14 local_random_walk 30 -285.6817132175697 4.804706124999939
# F14 local_random_walk 30 -285.7322677022934 4.835388250001415
# F14 local_random_walk 30 -285.67774554348665 4.968157749997772
# F14 spiral_dynamic 30 -285.5670227459967 15.400060708001547
# F14 spiral_dynamic 30 -285.70508948460207 15.36784533300306
# F14 spiral_dynamic 30 -285.73906800570455 15.400365125002281
# F14 spiral_dynamic 30 -285.49723979646024 15.388079917000141
# F14 spiral_dynamic 30 -285.8059600591342 15.393860958000005
# F14 spiral_dynamic 30 -285.77714858580805 15.408529542000906
# F14 swarm_dynamic 30 -285.68955834766007 4.7781774579998455
# F14 swarm_dynamic 30 -285.70689827904505 4.775873042002786
# F14 swarm_dynamic 30 -285.7960059059672 4.774099207999825
# F14 swarm_dynamic 30 -285.6287792534801 4.772755874997529
# F14 swarm_dynamic 30 -285.82605456892674 4.766507874999661
# F14 swarm_dynamic 30 -285.6726113310599 4.775089499999012
# F14 swarm_dynamic 30 -285.9734272102086 4.781237207997037
# F14 swarm_dynamic 30 -286.00485249097216 4.782115375001013
# F14 swarm_dynamic 30 -285.84476146928006 4.86409570899923
# F14 swarm_dynamic 30 -286.08812319733323 4.785044708001806
# F14 swarm_dynamic 30 -285.7200365248342 4.775268708999647
# F14 swarm_dynamic 30 -285.6673588301973 4.783120583000709
# F14-50D-basic_metaheuristic :: BasicMH 1 of 66, Perf: -275.78030725256735
# F14-50D-basic_metaheuristic :: BasicMH 2 of 66, Perf: -275.38284976151755
# F14-50D-basic_metaheuristic :: BasicMH 3 of 66, Perf: -275.8050623631101
# F14-50D-basic_metaheuristic :: BasicMH 4 of 66, Perf: -276.19715173521723
# F14-50D-basic_metaheuristic :: BasicMH 5 of 66, Perf: -275.29560091575746
# F14-50D-basic_metaheuristic :: BasicMH 6 of 66, Perf: -275.88767131009973
# F14-50D-basic_metaheuristic :: BasicMH 7 of 66, Perf: -276.07175858501853
# F14-50D-basic_metaheuristic :: BasicMH 8 of 66, Perf: -275.2502353527016
# F14-50D-basic_metaheuristic :: BasicMH 9 of 66, Perf: -275.913741968452
# F14-50D-basic_metaheuristic :: BasicMH 10 of 66, Perf: -276.1321579910151
# F14-50D-basic_metaheuristic :: BasicMH 11 of 66, Perf: -275.74817839227245
# F14-50D-basic_metaheuristic :: BasicMH 12 of 66, Perf: -275.7109624795801
# F14-50D-basic_metaheuristic :: BasicMH 13 of 66, Perf: -275.74701879964437
# F14-50D-basic_metaheuristic :: BasicMH 14 of 66, Perf: -275.7375052197043
# F14-50D-basic_metaheuristic :: BasicMH 15 of 66, Perf: -275.75608619660204
# F14-50D-basic_metaheuristic :: BasicMH 16 of 66, Perf: -275.73816440349026
# F14-50D-basic_metaheuristic :: BasicMH 17 of 66, Perf: -275.7846878678257
# F14-50D-basic_metaheuristic :: BasicMH 18 of 66, Perf: -275.71830912248214
# F14-50D-basic_metaheuristic :: BasicMH 19 of 66, Perf: -275.9319380046012
# F14-50D-basic_metaheuristic :: BasicMH 20 of 66, Perf: -275.8526382072222
# F14-50D-basic_metaheuristic :: BasicMH 21 of 66, Perf: -275.8228919674798
# F14-50D-basic_metaheuristic :: BasicMH 22 of 66, Perf: -275.8740912015997
# F14-50D-basic_metaheuristic :: BasicMH 23 of 66, Perf: -275.8469119554417
# F14-50D-basic_metaheuristic :: BasicMH 24 of 66, Perf: -275.91730669556404
# F14-50D-basic_metaheuristic :: BasicMH 25 of 66, Perf: -275.9321188497834
# F14-50D-basic_metaheuristic :: BasicMH 26 of 66, Perf: -276.0691738552552
# F14-50D-basic_metaheuristic :: BasicMH 27 of 66, Perf: -275.98533640947414
# F14-50D-basic_metaheuristic :: BasicMH 28 of 66, Perf: -275.9552241666445
# F14-50D-basic_metaheuristic :: BasicMH 29 of 66, Perf: -275.8915316219247
# F14-50D-basic_metaheuristic :: BasicMH 30 of 66, Perf: -275.99285883143205
# F14-50D-basic_metaheuristic :: BasicMH 31 of 66, Perf: -275.60273284449624
# F14-50D-basic_metaheuristic :: BasicMH 32 of 66, Perf: -275.76845224426717
# F14-50D-basic_metaheuristic :: BasicMH 33 of 66, Perf: -275.6192055436943
# F14-50D-basic_metaheuristic :: BasicMH 34 of 66, Perf: -275.77392272498776
# F14-50D-basic_metaheuristic :: BasicMH 35 of 66, Perf: -275.7702941048459
# F14-50D-basic_metaheuristic :: BasicMH 36 of 66, Perf: -275.73191945177257
# F14-50D-basic_metaheuristic :: BasicMH 37 of 66, Perf: -275.9890215224043
# F14-50D-basic_metaheuristic :: BasicMH 38 of 66, Perf: -275.93106676131913
# F14-50D-basic_metaheuristic :: BasicMH 39 of 66, Perf: -275.8922353531428
# F14-50D-basic_metaheuristic :: BasicMH 40 of 66, Perf: -276.07951097255597
# F14-50D-basic_metaheuristic :: BasicMH 41 of 66, Perf: -275.98472188270966
# F14-50D-basic_metaheuristic :: BasicMH 42 of 66, Perf: -276.0794149431283
# F14-50D-basic_metaheuristic :: BasicMH 43 of 66, Perf: -275.75976206465424
# F14-50D-basic_metaheuristic :: BasicMH 44 of 66, Perf: -275.75834719165175
# F14-50D-basic_metaheuristic :: BasicMH 45 of 66, Perf: -275.74778255155576
# F14-50D-basic_metaheuristic :: BasicMH 46 of 66, Perf: -275.8672593165122
# F14-50D-basic_metaheuristic :: BasicMH 47 of 66, Perf: -275.88365605916863
# F14-50D-basic_metaheuristic :: BasicMH 48 of 66, Perf: -275.786161071744
# F14-50D-basic_metaheuristic :: BasicMH 49 of 66, Perf: -275.8548319896148
# F14-50D-basic_metaheuristic :: BasicMH 50 of 66, Perf: -275.60236538541614
# F14-50D-basic_metaheuristic :: BasicMH 51 of 66, Perf: -275.8253063179902
# F14-50D-basic_metaheuristic :: BasicMH 52 of 66, Perf: -275.4992457365027
# F14-50D-basic_metaheuristic :: BasicMH 53 of 66, Perf: -275.7798591127442
# F14-50D-basic_metaheuristic :: BasicMH 54 of 66, Perf: -275.93383414872477
# F14-50D-basic_metaheuristic :: BasicMH 55 of 66, Perf: -275.83626457664303
# F14-50D-basic_metaheuristic :: BasicMH 56 of 66, Perf: -275.81930929070796
# F14-50D-basic_metaheuristic :: BasicMH 57 of 66, Perf: -275.7395824023564
# F14-50D-basic_metaheuristic :: BasicMH 58 of 66, Perf: -275.7904621071931
# F14-50D-basic_metaheuristic :: BasicMH 59 of 66, Perf: -275.8181109013797
# F14-50D-basic_metaheuristic :: BasicMH 60 of 66, Perf: -275.90865022275364
# F14-50D-basic_metaheuristic :: BasicMH 61 of 66, Perf: -276.057042773873
# F14-50D-basic_metaheuristic :: BasicMH 62 of 66, Perf: -276.0330482354656
# F14-50D-basic_metaheuristic :: BasicMH 63 of 66, Perf: -276.09415153354513
# F14-50D-basic_metaheuristic :: BasicMH 64 of 66, Perf: -276.3295271694496
# F14-50D-basic_metaheuristic :: BasicMH 65 of 66, Perf: -275.7731936097697
# F14-50D-basic_metaheuristic :: BasicMH 66 of 66, Perf: -275.74646486539683
# F14 with bmhs done!
# F14 random_search 50 -275.78030725256735 7.402597083000728
# F14 central_force_dynamic 50 -275.38284976151755 9.771329291997972
# F14 central_force_dynamic 50 -275.8050623631101 9.750354207997589
# F14 central_force_dynamic 50 -276.19715173521723 9.740359334002278
# F14 central_force_dynamic 50 -275.29560091575746 9.95635966700138
# F14 central_force_dynamic 50 -275.88767131009973 10.004413042002852
# F14 central_force_dynamic 50 -276.07175858501853 9.764381125001819
# F14 central_force_dynamic 50 -275.2502353527016 9.78602729100021
# F14 central_force_dynamic 50 -275.913741968452 9.752116875002685
# F14 central_force_dynamic 50 -276.1321579910151 9.73082654099926
# F14 differential_mutation 50 -275.74817839227245 14.57712412500041
# F14 differential_mutation 50 -275.7109624795801 14.596209875002387
# F14 differential_mutation 50 -275.74701879964437 14.64238404200296
# F14 differential_mutation 50 -275.7375052197043 14.58016708300056
# F14 differential_mutation 50 -275.75608619660204 14.54521858299995
# F14 differential_mutation 50 -275.73816440349026 14.549051042002247
# F14 differential_mutation 50 -275.7846878678257 14.527797791000921
# F14 differential_mutation 50 -275.71830912248214 14.541994874998636
# F14 firefly_dynamic 50 -275.9319380046012 10.48311491700224
# F14 firefly_dynamic 50 -275.8526382072222 10.496255542002473
# F14 firefly_dynamic 50 -275.8228919674798 10.494161875001737
# F14 firefly_dynamic 50 -275.8740912015997 10.499093082999025
# F14 firefly_dynamic 50 -275.8469119554417 10.494496125000296
# F14 firefly_dynamic 50 -275.91730669556404 10.49431524999818
# F14 genetic_crossover 50 -275.9321188497834 19.25188395800069
# F14 genetic_crossover 50 -276.0691738552552 18.919826166002167
# F14 genetic_crossover 50 -275.98533640947414 18.786855792001006
# F14 genetic_crossover 50 -275.9552241666445 19.232072082999366
# F14 genetic_crossover 50 -275.8915316219247 18.921862499999406
# F14 genetic_crossover 50 -275.99285883143205 18.763086167000438
# F14 gravitational_search 50 -275.60273284449624 9.722528334001254
# F14 gravitational_search 50 -275.76845224426717 9.792160832999798
# F14 gravitational_search 50 -275.6192055436943 9.725722792001761
# F14 gravitational_search 50 -275.77392272498776 9.72471058299925
# F14 gravitational_search 50 -275.7702941048459 9.712548125000467
# F14 gravitational_search 50 -275.73191945177257 9.712128667000798
# F14 random_flight 50 -275.9890215224043 14.411125708000327
# F14 random_flight 50 -275.93106676131913 14.42063270899962
# F14 random_flight 50 -275.8922353531428 14.437358125000173
# F14 random_flight 50 -276.07951097255597 14.416088750000199
# F14 random_flight 50 -275.98472188270966 14.440616125000815
# F14 random_flight 50 -276.0794149431283 14.45203875000152
# F14 local_random_walk 50 -275.75976206465424 7.2784567910021
# F14 local_random_walk 50 -275.75834719165175 7.346403416999237
# F14 local_random_walk 50 -275.74778255155576 7.538708542000677
# F14 local_random_walk 50 -275.8672593165122 7.265381541998067
# F14 local_random_walk 50 -275.88365605916863 7.318590249997214
# F14 local_random_walk 50 -275.786161071744 7.513328208999155
# F14 spiral_dynamic 50 -275.8548319896148 56.586969125000905
# F14 spiral_dynamic 50 -275.60236538541614 56.55929487499816
# F14 spiral_dynamic 50 -275.8253063179902 56.652807709000626
# F14 spiral_dynamic 50 -275.4992457365027 56.60203116699995
# F14 spiral_dynamic 50 -275.7798591127442 56.642719874998875
# F14 spiral_dynamic 50 -275.93383414872477 56.73069675000079
# F14 swarm_dynamic 50 -275.83626457664303 7.266537582996534
# F14 swarm_dynamic 50 -275.81930929070796 7.2508437920005235
# F14 swarm_dynamic 50 -275.7395824023564 7.246004790998995
# F14 swarm_dynamic 50 -275.7904621071931 7.257509999999456
# F14 swarm_dynamic 50 -275.8181109013797 7.25343837499895
# F14 swarm_dynamic 50 -275.90865022275364 7.24395120799818
# F14 swarm_dynamic 50 -276.057042773873 7.245285249999142
# F14 swarm_dynamic 50 -276.0330482354656 7.253714750000654
# F14 swarm_dynamic 50 -276.09415153354513 7.246257833998243
# F14 swarm_dynamic 50 -276.3295271694496 7.245740625003236
# F14 swarm_dynamic 50 -275.7731936097697 7.259636916998716
# F14 swarm_dynamic 50 -275.74646486539683 7.2993014580024465

# %%
json_object = json.dumps(results_bmhs, indent=4)
with open('bmhs_cec2005_results.json', 'w') as outfile:
  outfile.write(json_object)

# %%
json_object = json.dumps(results_dlstm_from_trained, indent=4)
with open('dlstm_from_trained_model_cec2005_results.json', 'w') as outfile:
  outfile.write(json_object)
